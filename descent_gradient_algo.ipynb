# %% [markdown]
# <a href="https://colab.research.google.com/github/Romesa3971/assignment1/blob/main/descent_gradient_algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data for linear regression
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.rand(100, 1)

# Define the cost function (mean squared error)
def compute_cost(theta, X, y):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1 / (2 * m)) * np.sum(np.square(predictions - y))
    return cost

# Gradient descent function
def gradient_descent(X, y, theta, learning_rate, num_iterations):
    m = len(y)
    cost_history = []

    for i in range(num_iterations):
        gradient = (1 / m) * X.T.dot(X.dot(theta) - y)
        theta -= learning_rate * gradient
        cost = compute_cost(theta, X, y)
        cost_history.append(cost)

    return theta, cost_history

# Add a column of ones to the input data for the intercept term
X_b = np.c_[np.ones((X.shape[0], 1)), X]

# Initialize theta (parameters)
theta = np.random.rand(2, 1)

# Set hyperparameters
learning_rate = 0.1
num_iterations = 100

# Perform gradient descent
theta, cost_history = gradient_descent(X_b, y, theta, learning_rate, num_iterations)

# Plot the cost history to visualize the convergence
plt.plot(range(num_iterations), cost_history)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Gradient Descent Convergence')
plt.show()

# Output the final theta values
print("Theta found by gradient descent:", theta)

# Predict a new value
new_X = np.array([[1, 2]])  # Feature vector [1, 2]
prediction = new_X.dot(theta)
print("Prediction for input [1, 2]:", prediction)
# Out:
# Theta found by gradient descent: [[4.31177859]
#  [3.18682611]]
# Prediction for input [1, 2]: [[10.68543082]]
